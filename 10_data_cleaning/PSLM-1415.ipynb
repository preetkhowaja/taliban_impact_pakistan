# %%
import pandas as pd

# %%
df2 = pd.read_stata("1415_sec_c.dta", convert_categoricals=False)

# %%
df2["hhcode"] = df2["hhcode"].astype("str")

# cleaning admitted & enrolled
df2["ever_admitted"] = "no"
df2.loc[(df2["scq03"] == 1), "ever_admitted"] = "yes"

df2["currently_enrolled"] = "no"
df2.loc[(df2["scq05"] == 1), "currently_enrolled"] = "yes"

df2["max_level_achieved"] = df2["scq04"]

# %%
# Reduce to the questions of interest (4 questions):
df2_rel = df2[
    [
        "hhcode",
        "idc",
        "ever_admitted",
        "currently_enrolled",
        "region",
        "province"
    ]
].copy()

# %%
df20 = pd.read_stata("1415_sec_b.dta")

# %%
df20.sample(10)
# Out:
#               hhcode       psu     province region    district  sec  idc  \
# 340646  3.141001e+09  31410011        sindh  rural     larkana  00B    4
# 64699   1.422200e+09  14222004           kp  urban    peshawar  00B    2
# 54169   1.311002e+09  13110015           kp  rural      mardan  00B    4
# 167204  2.412200e+09  24122001       punjab  urban  gujranwala  00B    3
# 15425   1.151000e+09  11510003           kp  rural     shangla  00B   10
# 119793  2.221004e+09  22210044       punjab  rural     bhakkar  00B    3
# 484300  4.421001e+09  44210010  balochistan  rural  jaffarabad  00B    7
# 493426  4.511001e+09  45110007  balochistan  rural       kalat  00B    2
# 133297  2.241004e+09  22410043       punjab  rural    mianwali  00B    3
# 510817  6.111000e+09  61110004       punjab  rural   islamabad  00B    2
#
#                  sbq02                        sbq03   sbq04    sbq05  sbq61  \
# 340646  brother\sister  main provider away for work  female  present   1989
# 64699           spouse                       others  female  present   1976
# 54169      grand child                 family elder    male  present   2011
# 167204    son/daughter       main economic provider  female  present   2005
# 15425     son/daughter       main economic provider    male  present   2007
# 119793    son/daughter       main economic provider  female  present   1992
# 484300    son/daughter                 family elder  female  present   2008
# 493426          spouse                 family elder  female  present   1989
# 133297    son/daughter       main economic provider    male  present   2001
# 510817    son/daughter  main provider away for work  female  present   2002
#
#        sbq62 sbq63  age                    sbq07  sbq08  sbq09  sbq10 sbq11
# 340646    00    00   25  unmarried/never married    NaN      3     98   yes
# 64699     00    00   38        currently married    1.0     99     99   yes
# 54169     09    00    3  unmarried/never married    NaN     99      2   yes
# 167204    00    00    9  unmarried/never married    NaN      1      2   yes
# 15425     03    15    7  unmarried/never married    NaN      1      2   yes
# 119793    00    00   22  unmarried/never married    NaN      1      2   yes
# 484300    00    00    6  unmarried/never married    NaN      1      2   yes
# 493426    00    00   25        currently married    1.0     99     99   yes
# 133297    00    00   13  unmarried/never married    NaN      1      2   yes
# 510817    00    00   12  unmarried/never married    NaN     99      1   yes

# %%
df20["hhcode"] = df20["hhcode"].astype("str")

df20['sex'] = df20['sbq04']
df20['marital_status'] = df20['sbq07']
df20['subprovince'] = df20['district']

# %%
df20_rel = df20[['hhcode', 'age','idc', 'sex', 'marital_status', 'subprovince']].copy()

# %%
years14_15 = pd.merge(df2_rel, df20_rel, on=["hhcode", "idc"], how='inner', indicator=False)

# %%
years14_15 = years14_15.loc[(years14_15["age"] > 4)&(years14_15["age"] <= 15)]

years14_15.loc[(years14_15["region"] == 1), 'region'] = 'urban'
years14_15.loc[(years14_15["region"] == 2), 'region'] = 'rural'

years14_15["subprovince code"] = years14_15["hhcode"].apply(lambda x: x[0:4])
years14_15["subprovince code"] = years14_15["subprovince code"].astype("int")

years14_15["province"] = years14_15["province"].astype("int")

years14_15["province"] = years14_15["province"].map(
    {1: "K.P.K", 2: "Punjab", 3: "Sindh", 4: "Balochistan"}
)

# modifying marital status to align with desired output
years14_15["marital_status"].replace(
    [
        "unmarried/never married",
        "currently married",
        "widow/widower",
        "divorced",
        "nikah has been solemnised but the rukhsati has  not taken place",
    ],
    [1, 2, 3, 4, 5],
    inplace=True,
)

years14_15.subprovince = years14_15.subprovince.str.capitalize()

years14_15['year'] = 2014

# %%
years14_15.province.unique()
# Out:
# array(['K.P.K', 'Punjab', 'Sindh', 'Balochistan'], dtype=object)

# %%
years14_15.sample(10)
# Out:
#               hhcode  idc ever_admitted currently_enrolled region  \
# 245119  2841005413.0    3            no                 no  urban
# 82560   1721000907.0    5           yes                yes  urban
# 14035   1151000503.0    4           yes                yes  urban
# 384750  3441002901.0    3            no                 no  urban
# 75075   1621001605.0    4           yes                yes  urban
# 159228  2441000413.0    8           yes                yes  urban
# 407882  4231000116.0    5           yes                yes  urban
# 63557   1511002204.0    3           yes                yes  urban
# 49480   1312000104.0    6           yes                yes  rural
# 95832   2141000907.0    5           yes                yes  urban
#
#            province  age     sex  marital_status      subprovince  \
# 245119       Punjab   14    male               1     Muzaffargarh
# 82560         K.P.K    8    male               1             Tank
# 14035         K.P.K   14    male               1          Shangla
# 384750        Sindh   10  female               1       Tharparkar
# 75075         K.P.K   11  female               1     Lakki marwat
# 159228       Punjab   12  female               1  Mandi bahauddin
# 407882  Balochistan   10    male               1         Musakhel
# 63557         K.P.K   12    male               1            Kohat
# 49480         K.P.K   14    male               1           Mardan
# 95832        Punjab   12  female               1          Chakwal
#
#         subprovince code  year
# 245119              2841  2014
# 82560               1721  2014
# 14035               1151  2014
# 384750              3441  2014
# 75075               1621  2014
# 159228              2441  2014
# 407882              4231  2014
# 63557               1511  2014
# 49480               1312  2014
# 95832               2141  2014

# %%
years14_15.to_csv("years14_15_f.csv")
