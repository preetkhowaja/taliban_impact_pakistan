# %% [markdown]
# # The Big Merge File
# :)

# %%
import pandas as pd

# %%
# Imports
yr04 = pd.read_csv(
    "/Users/clarissaache/Documents/IDS 701/uds-2022-ids-701-team-3/20_analysis/enrollment_clean/years04_05_merge_diff.csv"
)
yr04["year"] = 2004

yr05 = pd.read_csv(
    "/Users/clarissaache/Documents/IDS 701/uds-2022-ids-701-team-3/20_analysis/enrollment_clean/years05_06_merge_diff.csv"
)
yr05["year"] = 2005

yr06 = pd.read_csv(
    "/Users/clarissaache/Documents/IDS 701/uds-2022-ids-701-team-3/20_analysis/enrollment_clean/years06_07_merge_diff.csv"
)
yr06["year"] = 2006

yr07 = pd.read_csv(
    "/Users/clarissaache/Documents/IDS 701/uds-2022-ids-701-team-3/20_analysis/enrollment_clean/years07_08_merge_diff.csv"
)
yr07["year"] = 2007

yr08 = pd.read_csv(
    "/Users/clarissaache/Documents/IDS 701/uds-2022-ids-701-team-3/20_analysis/enrollment_clean/years08_09_merge_diff.csv"
)
yr08["year"] = 2008

yr10 = pd.read_csv(
    "/Users/clarissaache/Documents/IDS 701/uds-2022-ids-701-team-3/20_analysis/enrollment_clean/years10_11_merge_diff.csv"
)
yr10["year"] = 2010

yr11 = pd.read_csv(
    "/Users/clarissaache/Documents/IDS 701/uds-2022-ids-701-team-3/20_analysis/enrollment_clean/years11_12_merge_diff.csv"
)
yr11["year"] = 2011

yr12 = pd.read_csv(
    "/Users/clarissaache/Documents/IDS 701/uds-2022-ids-701-team-3/20_analysis/enrollment_clean/years12_13_merge_diff.csv"
)
yr12["year"] = 2012

yr13 = pd.read_csv(
    "/Users/clarissaache/Documents/IDS 701/uds-2022-ids-701-team-3/20_analysis/enrollment_clean/years13_14_merge_diff.csv"
)
yr13["year"] = 2013

yr14 = pd.read_csv(
    "/Users/clarissaache/Documents/IDS 701/uds-2022-ids-701-team-3/20_analysis/enrollment_clean/years14_15_merge_diff.csv"
)
yr14["year"] = 2014

yr15 = pd.read_csv(
    "/Users/clarissaache/Documents/IDS 701/uds-2022-ids-701-team-3/20_analysis/enrollment_clean/years15_16_merge_diff.csv"
)
yr15["year"] = 2015

yr18 = pd.read_csv(
    "/Users/clarissaache/Documents/IDS 701/uds-2022-ids-701-team-3/20_analysis/enrollment_clean/years18_19_merge_diff.csv"
)
yr18["year"] = 2018

yr19 = pd.read_csv(
    "/Users/clarissaache/Documents/IDS 701/uds-2022-ids-701-team-3/20_analysis/enrollment_clean/years19_20_merge_diff.csv"
)
yr19["year"] = 2019

# %%
df = pd.concat(
    [yr04, yr05, yr06, yr07, yr08, yr10, yr11, yr12, yr13, yr14, yr15, yr18, yr19]
)
df["subprovince"] = df["subprovince"].str.rstrip()

# %%
df[df["year"] == 2006]
# Out:
#      Unnamed: 0     sex      subprovince region  sample_population  \
# 0             0    male       Abbottabad  rural                307
# 1             1    male       Abbottabad  urban                  0
# 2             2    male           Attock  rural                369
# 3             3    male           Attock  urban                  0
# 4             4    male           Awaran  rural                289
# 5             5    male           Awaran  urban                  0
# 6             6    male            Badin  rural                845
# 7             7    male            Badin  urban                  0
# 8             8    male     Bahawalnager  rural                777
# 9             9    male     Bahawalnager  urban                  0
# 10           10    male       Bahawalpur  rural                773
# 11           11    male       Bahawalpur  urban                  0
# 12           12    male            Bannu  rural                532
# ...

# %%
# Unique # of cities
df.subprovince.nunique()
# Out:
# 279

# %%
# Replaces:
df["subprovince"] = df["subprovince"].replace("Ättock", "Attock")
df["subprovince"] = df["subprovince"].replace("Abbottabad", "Abbotabad")
df["subprovince"] = df["subprovince"].replace("Bahawalnagar", "Bahawal Nagar")
df["subprovince"] = df["subprovince"].replace("Bahawalnager", "Bahawal Nagar")

df["subprovince"] = df["subprovince"].replace("Bhakhar", "Bhakkar")
df["subprovince"] = df["subprovince"].replace("Bhakar", "Bhakkar")
df["subprovince"] = df["subprovince"].replace("Baddin", "Badin")

df["subprovince"] = df["subprovince"].replace("Barkhen", "Barkhan")

df["subprovince"] = df["subprovince"].replace("Bhawalpur", "Bahawalpur")
df["subprovince"] = df["subprovince"].replace("Bolan/ Kachhi", "Bolan/Kachhi")
df["subprovince"] = df["subprovince"].replace("Bolan/Kachhi", "Bolan/Kachhi")
df["subprovince"] = df["subprovince"].replace("Bolan/ kachhi", "Bolan/Kachhi")
df["subprovince"] = df["subprovince"].replace("Bolan/Kachni", "Bolan/Kachhi")

df["subprovince"] = df["subprovince"].replace("Bonair", "Buner")
df["subprovince"] = df["subprovince"].replace("Bunair", "Buner")


df["subprovince"] = df["subprovince"].replace("Chaghi", "Chagai")
df["subprovince"] = df["subprovince"].replace("Chaghai", "Chagai")
df["subprovince"] = df["subprovince"].replace("Chaghi", "Chagai")
df["subprovince"] = df["subprovince"].replace("Charsada", "Charsadda")
df["subprovince"] = df["subprovince"].replace("D. G. Khan", "D.G. Khan")
df["subprovince"] = df["subprovince"].replace("Dera Ghazi Khan", "D.G. Khan")
df["subprovince"] = df["subprovince"].replace("D. g. khan", "D.G. Khan")
df["subprovince"] = df["subprovince"].replace("D.G.Khan", "D.G. Khan")
df["subprovince"] = df["subprovince"].replace("D.g khan", "D.G. Khan")


df["subprovince"] = df["subprovince"].replace("D.I.Khan", "D.I. Khan")
df["subprovince"] = df["subprovince"].replace("D. i. khan", "D.I. Khan")
df["subprovince"] = df["subprovince"].replace("D. I. Khan", "D.I. Khan")
df["subprovince"] = df["subprovince"].replace("Dera Ismail Khan", "D.I. Khan")
df["subprovince"] = df["subprovince"].replace("D.i.khan", "D.I. Khan")

df["subprovince"] = df["subprovince"].replace("Dera bugti", "Dera Bugti")
df["subprovince"] = df["subprovince"].replace("Deara Bughti", "Dera Bugti")
df["subprovince"] = df["subprovince"].replace("Dera Bughti", "Dera Bugti")

df["subprovince"] = df["subprovince"].replace("Gujranwala", "Gujaranwala")
df["subprovince"] = df["subprovince"].replace("Gawadar", "Gwadar")

df["subprovince"] = df["subprovince"].replace("Haifzabad", "Hafizabad")
df["subprovince"] = df["subprovince"].replace("Hafaizabad", "Hafizabad")
df["subprovince"] = df["subprovince"].replace("Hzara", "Hazara")
df["subprovince"] = df["subprovince"].replace("Pak Pattain", "Pakpattan")
df["subprovince"] = df["subprovince"].replace("Pakpaten", "Pakpattan")
df["subprovince"] = df["subprovince"].replace("Pakpatan", "Pakpattan")
df["subprovince"] = df["subprovince"].replace("Pakpatten", "Pakpattan")

df["subprovince"] = df["subprovince"].replace("pishine", "Pishin")
df["subprovince"] = df["subprovince"].replace("Pishine", "Pishin")
df["subprovince"] = df["subprovince"].replace("Pashin", "Pishin")
df["subprovince"] = df["subprovince"].replace("Pershawar", "Peshawar")
df["subprovince"] = df["subprovince"].replace("Qillah Abdullah", "Qilla Abdullah")
df["subprovince"] = df["subprovince"].replace("QillahAbdullah", "Qilla Abdullah")
df["subprovince"] = df["subprovince"].replace("Killa Abdullah", "Qilla Abdullah")
df["subprovince"] = df["subprovince"].replace("Qilla abdullah", "Qilla Abdullah")

df["subprovince"] = df["subprovince"].replace("Qillah Saifullah", "Qilla Saifullah")
df["subprovince"] = df["subprovince"].replace("Qillah Salifullah", "Qilla Saifullah")
df["subprovince"] = df["subprovince"].replace("QillahSaifullah", "Qilla Saifullah")
df["subprovince"] = df["subprovince"].replace("Killa Saifullah", "Qilla Saifullah")
df["subprovince"] = df["subprovince"].replace("Qilla saifullah", "Qilla Saifullah")

df["subprovince"] = df["subprovince"].replace("Quetta (Div)", "Quetta")
df["subprovince"] = df["subprovince"].replace("R.Y.Khan", "Rahim Yar Khan")
df["subprovince"] = df["subprovince"].replace("Rahim yar khan", "Rahim Yar Khan")
df["subprovince"] = df["subprovince"].replace("Rajaanpur", "Rajanpur")
df["subprovince"] = df["subprovince"].replace(
    "Shaheed Banazir Abad", "Shaheed Benazir Abad"
)
df["subprovince"] = df["subprovince"].replace(
    "Shaheed Benazirabad", "Shaheed Benazir Abad"
)
df["subprovince"] = df["subprovince"].replace(
    "Shaheed benazir abad", "Shaheed Benazir Abad"
)
df["subprovince"] = df["subprovince"].replace("Sheerani", "Sherani")
df["subprovince"] = df["subprovince"].replace("Sibbi (Div)", "Sibbi")
df["subprovince"] = df["subprovince"].replace("Sibi", "Sibbi")
df["subprovince"] = df["subprovince"].replace("Sijawal", "Sujawal")
df["subprovince"] = df["subprovince"].replace("Sukkar", "Sukkur")
df["subprovince"] = df["subprovince"].replace("T.T. Singh", "Toba Tek Singh")
df["subprovince"] = df["subprovince"].replace("T.T.Singh", "Toba Tek Singh")
df["subprovince"] = df["subprovince"].replace("T.t. singh", "Toba Tek Singh")
df["subprovince"] = df["subprovince"].replace("T.t singh", "Toba Tek Singh")
df["subprovince"] = df["subprovince"].replace("Sarghodha", "Sargodha")
df["subprovince"] = df["subprovince"].replace("Sheani", "Sherani")
df["subprovince"] = df["subprovince"].replace("Shikarpur", "Shiokarpur")

df["subprovince"] = df["subprovince"].replace("Tando Muhammad", "Tando Muhammad Khan")
df["subprovince"] = df["subprovince"].replace("Tando Muhd Khan", "Tando Muhammad Khan")
df["subprovince"] = df["subprovince"].replace(
    "Tando mohammad khan", "Tando Muhammad Khan"
)
df["subprovince"] = df["subprovince"].replace("Tando mohd khan", "Tando Muhammad Khan")

df["subprovince"] = df["subprovince"].replace("TandoAllah Yar", "Tando Allahyar")
df["subprovince"] = df["subprovince"].replace("Tando Allah Yar", "Tando Allahyar")
df["subprovince"] = df["subprovince"].replace("Tando allah yar", "Tando Allahyar")
df["subprovince"] = df["subprovince"].replace("Tor Garh", "Torghar")
df["subprovince"] = df["subprovince"].replace("Tor ghar", "Torghar")
df["subprovince"] = df["subprovince"].replace("Torgarh", "Torghar")

df["subprovince"] = df["subprovince"].replace("Umer kot", "Umer Kot")
df["subprovince"] = df["subprovince"].replace("Ümer kot", "Umer Kot")
df["subprovince"] = df["subprovince"].replace("Upper dir", "Upper Dir")
df["subprovince"] = df["subprovince"].replace("UpperDir", "Upper Dir")
df["subprovince"] = df["subprovince"].replace("Zhob (Div)", "Zhob")

# %%
df["subprovince"] = df["subprovince"].replace("Jaccobabad", "Jacobabad")
df["subprovince"] = df["subprovince"].replace("Jaffarabad", "Jafarabad")
df["subprovince"] = df["subprovince"].replace("Jafrabad", "Jafarabad")
df["subprovince"] = df["subprovince"].replace("Jhal magsi", "Jhal Magsi")
df["subprovince"] = df["subprovince"].replace("JhalMagsi", "Jhal Magsi")
df["subprovince"] = df["subprovince"].replace("Jehlum", "Jhelum")

df["subprovince"] = df["subprovince"].replace("Kachhi/ Bolan", "Kachhi")
df["subprovince"] = df["subprovince"].replace("Bolan/kachhi", "Kachhi")
df["subprovince"] = df["subprovince"].replace("Bolan/Kachhi", "Kachhi")

df["subprovince"] = df["subprovince"].replace("Kalat (Div)", "Kalat")
df["subprovince"] = df["subprovince"].replace("Karachi Central", "Karachi")
df["subprovince"] = df["subprovince"].replace("Karachi East", "Karachi")
df["subprovince"] = df["subprovince"].replace("Karachi Malir", "Karachi")
df["subprovince"] = df["subprovince"].replace("Karachi South", "Karachi")
df["subprovince"] = df["subprovince"].replace("Karachi West", "Karachi")
df["subprovince"] = df["subprovince"].replace("Kashmore", "Kashmor")
df["subprovince"] = df["subprovince"].replace("Kech", "Kech/Turbat")
df["subprovince"] = df["subprovince"].replace("Ketch/Turbat", "Kech/Turbat")
df["subprovince"] = df["subprovince"].replace("Keych/turbat", "Kech/Turbat")

df["subprovince"] = df["subprovince"].replace("Killa abdullah", "Qilla Saifullah")
df["subprovince"] = df["subprovince"].replace("Killa saifullah", "Killa Saifullah")
df["subprovince"] = df["subprovince"].replace("Lakki marwat", "Lakki Marwat")
df["subprovince"] = df["subprovince"].replace("LakkiMarwat", "Lakki Marwat")
df["subprovince"] = df["subprovince"].replace("Lasbella", "Lasbela")
df["subprovince"] = df["subprovince"].replace("Lasbilla", "Lasbela")
df["subprovince"] = df["subprovince"].replace("Layyah", "Layya")
df["subprovince"] = df["subprovince"].replace("Lodhrean", "Lodhran")

df["subprovince"] = df["subprovince"].replace("Lower dir", "Lower Dir")
df["subprovince"] = df["subprovince"].replace("LowerDir", "Lower Dir")
df["subprovince"] = df["subprovince"].replace("Makran (Div)", "Makran")
df["subprovince"] = df["subprovince"].replace("Malakand Protected", "Malakand")
df["subprovince"] = df["subprovince"].replace("Malakand Protected Area", "Malakand")
df["subprovince"] = df["subprovince"].replace("Mandi Bahuddin", "Mandi Bahauddin")
df["subprovince"] = df["subprovince"].replace("Mandi bahauddin", "Mandi Bahauddin")
df["subprovince"] = df["subprovince"].replace("Manshera", "Mansehra")
df["subprovince"] = df["subprovince"].replace("Mir pur Khas", "Mir Pur Khas")
df["subprovince"] = df["subprovince"].replace("MirPurKhas", "Mir Pur Khas")
df["subprovince"] = df["subprovince"].replace("Mirpur Khas", "Mir Pur Khas")
df["subprovince"] = df["subprovince"].replace("Mirpur khas", "Mir Pur Khas")
df["subprovince"] = df["subprovince"].replace("Mir pur khas", "Mir Pur Khas")
df["subprovince"] = df["subprovince"].replace("M ianwali", "Mianwali")
df["subprovince"] = df["subprovince"].replace("Mitiari", "Matiari")

df["subprovince"] = df["subprovince"].replace("MusaKhel", "Musa Khel")
df["subprovince"] = df["subprovince"].replace("Musa khel", "Musa Khel")
df["subprovince"] = df["subprovince"].replace("Musa", "Musa Khel")
df["subprovince"] = df["subprovince"].replace("Musakhel", "Musa Khel")
df["subprovince"] = df["subprovince"].replace("Muraffar Garh", "Muzaffar Garh")
df["subprovince"] = df["subprovince"].replace("Muzaffar garh", "Muzaffar Garh")
df["subprovince"] = df["subprovince"].replace("Muzaffargarh", "Muzaffar Garh")
df["subprovince"] = df["subprovince"].replace("Nankana Sahi", "Nankana Sahib")
df["subprovince"] = df["subprovince"].replace("Nankana sahib", "Nankana Sahib")
df["subprovince"] = df["subprovince"].replace("Naseerabad (Div)", "Nasirabad")
df["subprovince"] = df["subprovince"].replace("Nasirabad/ Tamboo", "Nasirabad")
df["subprovince"] = df["subprovince"].replace("Nasirabad/ tamboo", "Nasirabad")
df["subprovince"] = df["subprovince"].replace("Naushahro feroze", "Naushahro Feroze")
df["subprovince"] = df["subprovince"].replace("Nowshero Feroze", "Naushahro Feroze")
df["subprovince"] = df["subprovince"].replace("Nowshero Freoze", "Naushahro Feroze")
df["subprovince"] = df["subprovince"].replace("Nowsehra", "Nowshera")
df["subprovince"] = df["subprovince"].replace("Nawabsha", "Nawabshah")
df["subprovince"] = df["subprovince"].replace("Nowshero feroze", "Naushahro Feroze")
df["subprovince"] = df["subprovince"].replace("Nauski", "Nushki")

df["subprovince"] = df["subprovince"].replace("Umer kot", "Umer Kot")
df["subprovince"] = df["subprovince"].replace("Upper dir", "Upper Dir")
df["subprovince"] = df["subprovince"].replace("UpperDir", "Upper Dir")
df["subprovince"] = df["subprovince"].replace("Zhob (Div)", "Zhob")

# %%
list = df["subprovince"].unique().tolist()
list = sorted(list)
list
# Out:
# ['Abbotabad',
#  'Attock',
#  'Awaran',
#  'Badin',
#  'Bahawal Nagar',
#  'Bahawalpur',
#  'Bajur',
#  'Bannu',
#  'Barkhan',
#  'Batagram',
#  'Bhakkar',
#  'Bhawanagar',
#  'Buner',
#  'Chagai',
#  'Chakwal',
#  'Charsadda',
#  'Chiniot',
#  'Chitral',
#  'D.G. Khan',
#  'D.I. Khan',
#  'Dadu',
#  'Dera Bugti',
#  'Duki',
#  'Faisalabad',
#  'Ghotki',
#  'Gujaranwala',
#  'Gujrat',
#  'Gwadar',
#  'Hafizabad',
#  'Hangu',
#  'Haripur',
#  'Harnai',
#  'Hazara',
#  'Hyderabad',
#  'Islamabad',
#  'Jacobabad',
#  'Jafarabad',
#  'Jamshoro',
#  'Jhal Magsi',
#  'Jhang',
#  'Jhelum',
#  'Kachhi',
#  'Kalat',
#  'Kambar Shahdadkot',
#  'Karachi',
#  'Karak',
#  'Kashmor',
#  'Kasur',
#  'Kech/Turbat',
#  'Khairpur',
#  'Khanewal',
#  'Kharan',
#  'Khushab',
#  'Khuzdar',
#  'Khyber',
#  'Killa Saifullah',
#  'Kohat',
#  'Kohistan',
#  'Kohlu',
#  'Korangi',
#  'Kurram',
#  'Lahore',
#  'Lakki Marwat',
#  'Larkana',
#  'Lasbela',
#  'Layya',
#  'Lehri',
#  'Lodhran',
#  'Loralai',
# ...

# %%
# Year counts
pd.set_option("display.max_rows", None)
pd.crosstab(df["subprovince"], df["year"])
# Out:
# year                   2004  2005  2006  2007  2008  2010  2011  2012  2013  \
# subprovince
# Abbotabad                 4     4     4     4     4     4     4     4     4
# Attock                    4     4     4     4     4     4     4     4     4
# Awaran                    4     0     4     0     4     4     0     4     4
# Badin                     4     4     4     4     4     4     4     4     4
# Bahawal Nagar             4     4     4     4     4     4     4     0     4
# Bahawalpur                4     4     8     8     8     4     4     4     4
# Bajur                     0     0     0     0     0     0     0     0     0
# Bannu                     4     4     4     8     4     4     8     4     4
# Barkhan                   4     0     4     0     4     8     0     4     4
# Batagram                  4     4     4     4     4     4     4     4     4
# Bhakkar                   4     4     4     4     4     4     4     4     4
# ...

# %%
df.to_csv(
    "/Users/clarissaache/Documents/IDS 701/uds-2022-ids-701-team-3/20_analysis/big_merge.csv"
)

# %% [markdown]
# # Diff in Diff

# %%
df_clean = df.dropna(axis=0).copy()

# %%
# Treatment and pre-post variables

df_clean.loc[(df_clean["year"] >= 2010), "post_2009"] = 1
df_clean.loc[(df_clean["year"] < 2007), "post_2009"] = 0

df_clean["Treated"] = 0
df_clean.loc[(df_clean["sex"] == "female"), "Treated"] = 1

# Drop 0s in urban/rural
df_clean = df_clean.loc[df_clean["region"] != 0]
df_urban = df_clean.loc[df_clean["region"] == "urban"]
df_rural = df_clean.loc[df_clean["region"] == "rural"]

# %%
print(df_clean["sex"].value_counts())
print(df_clean["region"].value_counts())
df_clean.sample(3)
# Out:
# male      2302
# female    2302
# Name: sex, dtype: int64
# rural    2558
# urban    2046
# Name: region, dtype: int64
#      Unnamed: 0     sex subprovince region  sample_population  enrolled_total  \
# 16           16  female     Bhakkar  rural                133              66
# 103         103    male       Kohat  urban                189             147
# 134         134  female    Mianwali  rural                693             427
#
#      rate_enrollment  year  post_2009  Treated
# 16          0.496241  2011        1.0        1
# 103         0.777778  2008        NaN        0
# 134         0.616162  2019        1.0        1

# %%
import matplotlib.pyplot as plt

Y_t1_pre = df_clean.loc[
    (df_clean["post_2009"] == 0) & (df_clean["Treated"] == 1)
].copy()

# Years pre-treatment, treated = 0
Y_t0_pre = df_clean.loc[
    (df_clean["post_2009"] == 0) & (df_clean["Treated"] == 0)
].copy()

# Years post-treatment, treated = 1
Y_t1_post = df_clean.loc[
    (df_clean["post_2009"] == 1) & (df_clean["Treated"] == 1)
].copy()

# Years post-treatment, treated = 0
Y_t0_post = df_clean.loc[
    (df_clean["post_2009"] == 1) & (df_clean["Treated"] == 0)
].copy()

# %%
import altair as alt

base = (
    alt.Chart(Y_t1_pre, title="Difference in difference comparison")
    .mark_point()
    .encode(
        alt.X("year", scale=alt.Scale(zero=False)),
        alt.Y("rate_enrollment", scale=alt.Scale(zero=False)),
    )
)

base2 = (
    alt.Chart(Y_t0_pre)
    .mark_point()
    .encode(
        alt.X("year", scale=alt.Scale(zero=False)),
        alt.Y("rate_enrollment", scale=alt.Scale(zero=False)),
    )
)

# base3 = (
#     alt.Chart(Y_t0_post)
#     .mark_point()
#     .encode(
#         alt.X("year", scale=alt.Scale(zero=False)),
#         alt.Y("rate_enrollment", scale=alt.Scale(zero=False)),
#     )
# )

# base4 = (
#     alt.Chart(Y_t1_post)
#     .mark_point()
#     .encode(
#         alt.X("year", scale=alt.Scale(zero=False)),
#         alt.Y("rate_enrollment", scale=alt.Scale(zero=False)),
#     )
# )
# Adding linear regression to observe trend
(
    base
    + base2
    # + base3
    # + base4
    + base.transform_regression("year", "rate_enrollment").mark_line()
    + base2.transform_regression("year", "rate_enrollment").mark_line()
    # + base3.transform_regression("year", "rate_enrollment").mark_line()
    # + base4.transform_regression("year", "rate_enrollment").mark_line()
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## Rural Only

# %%
Y_t1_pre = df_rural.loc[
    (df_rural["post_2009"] == 0) & (df_rural["Treated"] == 1)
].copy()

# Years pre-treatment, treated = 0
Y_t0_pre = df_rural.loc[
    (df_rural["post_2009"] == 0) & (df_rural["Treated"] == 0)
].copy()

# Years post-treatment, treated = 1
Y_t1_post = df_rural.loc[
    (df_rural["post_2009"] == 1) & (df_rural["Treated"] == 1)
].copy()

# Years post-treatment, treated = 0
Y_t0_post = df_rural.loc[
    (df_rural["post_2009"] == 1) & (df_rural["Treated"] == 0)
].copy()

# %%
import altair as alt

base = (
    alt.Chart(Y_t1_pre, title="Difference in difference comparison")
    .mark_point()
    .encode(
        alt.X("year", scale=alt.Scale(zero=False)),
        alt.Y("rate_enrollment", scale=alt.Scale(zero=False)),
        color=alt.value("#FFAA00")
    )
)

base2 = (
    alt.Chart(Y_t0_pre)
    .mark_point()
    .encode(
        alt.X("year", scale=alt.Scale(zero=False)),
        alt.Y("rate_enrollment", scale=alt.Scale(zero=False)),
    )
)

# base3 = (
#     alt.Chart(Y_t0_post)
#     .mark_point()
#     .encode(
#         alt.X("year", scale=alt.Scale(zero=False)),
#         alt.Y("rate_enrollment", scale=alt.Scale(zero=False)),
#     )
# )

# base4 = (
#     alt.Chart(Y_t1_post)
#     .mark_point()
#     .encode(
#         alt.X("year", scale=alt.Scale(zero=False)),
#         alt.Y("rate_enrollment", scale=alt.Scale(zero=False)),
#     )
# )
# Adding linear regression to observe trend
(
    base
    + base2
    # + base3
    # + base4
    + base.transform_regression("year", "rate_enrollment").mark_line()
    + base2.transform_regression("year", "rate_enrollment").mark_line()
    # + base3.transform_regression("year", "rate_enrollment").mark_line()
    # + base4.transform_regression("year", "rate_enrollment").mark_line()
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # City where bombings happened vs. the rest

# %%
taliabn_dominance = [
    "South Waziristan",
    "North Waziristan",
    "Orakzai",
    "Kurram",
    "Khyber",
    "Mohmand",
    "Bajur",
    "Darra Adamkhel",
    "Swat",
    "Upper Dir",
    "Lower Dir",
    "Bannu",
    "Lakki Marwat",
    "Tank",
    "Peshawar",
    "Dera Ismail Khan",
    "Mardan",
    "Charsadda",
    "Kohat",
]

# %%
df_female = df_clean.loc[
    (df_clean["sex"] == "female") & (df_clean["region"] == "rural")
].copy()
df_female["Treated"] = 0
df_female.loc[(df_female["subprovince"].isin(taliabn_dominance)), "Treated"] = 1
df_female.sample(5)
# Out:
#      Unnamed: 0     sex  subprovince region  sample_population  \
# 274         274  female  Gujaranwala  rural                511
# 494         494  female        Swabi  rural                159
# 272         272  female      Chakwal  rural                343
# 176         176  female      Sahiwal  rural               1242
# 46           46  female       Gujrat  rural                114
#
#      enrolled_total  rate_enrollment  year  post_2009  Treated
# 274             438         0.857143  2012        1.0        0
# 494             106         0.666667  2018        1.0        0
# 272             277         0.807580  2008        NaN        0
# 176             805         0.648148  2019        1.0        0
# 46              108         0.947368  2011        1.0        0

# %%
Y_t1_pre = df_female.loc[
    (df_female["post_2009"] == 0) & (df_female["Treated"] == 1)
].copy()

# Years pre-treatment, treated = 0
Y_t0_pre = df_female.loc[
    (df_female["post_2009"] == 0) & (df_female["Treated"] == 0)
].copy()

# Years post-treatment, treated = 1
Y_t1_post = df_female.loc[
    (df_female["post_2009"] == 1) & (df_female["Treated"] == 1)
].copy()

# Years post-treatment, treated = 0
Y_t0_post = df_female.loc[
    (df_female["post_2009"] == 1) & (df_female["Treated"] == 0)
].copy()

# %%
# AVERAGE treatment effect:
delta_hat = (
    Y_t1_post["rate_enrollment"].mean() - Y_t1_pre["rate_enrollment"].mean()
) - (Y_t0_post["rate_enrollment"].mean() - Y_t0_pre["rate_enrollment"].mean())
delta_hat
# Out:
# 0.03216734948806638

# %%
base = (
    alt.Chart(Y_t1_pre, title="Enrollment Rate of Girls in Rural Areas before Taliban Incursion in 2007")
    .mark_point()
    .encode(
        alt.X("year", scale=alt.Scale(zero=False)),
        alt.Y("rate_enrollment", scale=alt.Scale(zero=False)),
        color=alt.value("#FFAA00"),
    )
)

base2 = (
    alt.Chart(Y_t0_pre)
    .mark_point()
    .encode(
        alt.X("year", scale=alt.Scale(zero=False), title='Year'),
        alt.Y("rate_enrollment", scale=alt.Scale(zero=False), title='Enrollment Rate'),
    )
)

# base3 = (
#     alt.Chart(Y_t0_post)
#     .mark_point()
#     .encode(
#         alt.X("year", scale=alt.Scale(zero=False)),
#         alt.Y("rate_enrollment", scale=alt.Scale(zero=False)),
#     )
# )

# base4 = (
#     alt.Chart(Y_t1_post)
#     .mark_point()
#     .encode(
#         alt.X("year", scale=alt.Scale(zero=False)),
#         alt.Y("rate_enrollment", scale=alt.Scale(zero=False)),
#         color=alt.value("#FFAA00"),
#     )
# )
# Adding linear regression to observe trend
(
    base
    + base2
    # + base3
    # + base4
    + base.transform_regression("year", "rate_enrollment").mark_line()
    + base2.transform_regression("year", "rate_enrollment").mark_line()
    # + base3.transform_regression("year", "rate_enrollment").mark_line()
    # + base4.transform_regression("year", "rate_enrollment").mark_line()
)
# Out:
# alt.LayerChart(...)

# %%
(
    df_female.loc[(df_female["subprovince"].isin(taliabn_dominance))]["region"]
    == "urban"
).sum()
# all regions controlled by taliban are rural
# Out:
# 0

# %%
pd.crosstab(df_female["subprovince"], df_female["Treated"])
# Out:
# Treated                 0   1
# subprovince
# Abbotabad              13   0
# Attock                 12   0
# Awaran                  8   0
# Badin                  12   0
# Bahawal Nagar          11   0
# Bahawalpur             12   0
# Bajur                   0   2
# Bannu                   0  13
# Barkhan                 9   0
# Batagram               12   0
# Bhakkar                12   0
# Bhawanagar              1   0
# Buner                  12   0
# Chagai                  7   0
# Chakwal                12   0
# Charsadda               0  13
# Chiniot                 7   0
# Chitral                13   0
# D.G. Khan              12   0
# D.I. Khan              13   0
# Dadu                   12   0
# Dera Bugti              9   0
# Duki                    1   0
# Faisalabad             12   0
# Ghotki                 12   0
# Gujaranwala            12   0
# Gujrat                 12   0
# Gwadar                  7   0
# Hafizabad              12   0
# ...

# %%
df_female[df_female["subprovince"] == "Orakzai"]
# Out:
#      Unnamed: 0     sex subprovince region  sample_population  enrolled_total  \
# 448         448  female     Orakzai  rural                 52              20
# 158         158  female     Orakzai  rural                453             151
#
#      rate_enrollment  year  post_2009  Treated
# 448         0.384615  2018        1.0        1
# 158         0.333333  2019        1.0        1

# %%
incomplete_taliban_ruled = [
    "Orakzai",
    "South Waziristan",
    "Okara",
    "North Waziristan",
    "Mohmand",
    "Kurram",
    "Khyber",
    "Bajur",
]

# %%
pd.crosstab(df_rural["subprovince"], df_rural["year"]).sum()
# Out:
# year
# 2004    194
# 2005    162
# 2006    202
# 2007    160
# 2008    220
# 2010    228
# 2011    180
# 2012    228
# 2013    232
# 2014    212
# 2015    234
# 2018     64
# 2019    242
# dtype: int64
